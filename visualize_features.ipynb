# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
data_dir = "/home/brian/GauFRe/data/slice-banana/dino_dim3/2x"

# %%
files = os.listdir(data_dir)

# %%
vis_feature = 0

# %%
features = np.load(os.path.join(data_dir, files[vis_feature]))
features -= features.min()
features /= features.max()
features.shape
# Out:
# (960, 536, 3)

# %%
plt.imshow(np.float32(features))
